# %%
# %matplotlib notebook

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#California csv

CA_file = "Resources/CA_weather_data.csv"

# %%
CA_df = pd.read_csv(CA_file)
CA_df.head()
# Out:
#          Date  Temperature (C)  Precipitation (mm)
# 0  2015-01-31        14.777097            0.024194
# 1  2015-02-28        16.025714            0.020357
# 2  2015-03-31        17.724839            0.034516
# 3  2015-04-30        17.172667            0.018333
# 4  2015-05-31        16.331290            0.065161

# %%
#Set variables for plotting

CA_temp = CA_df['Temperature (C)']
x_axis1 = CA_df['Date']

# %%
#Plot average temp 

CA_avg1 = plt.plot(x_axis1, CA_temp, color="blue", label="Avg Temperature (C)")

tick_locations = [value for value in x_axis1]
plt.xticks(tick_locations, x_axis1, rotation=90)

#Formatting
plt.title("Average Temp(C): San Diego, CA")
plt.xlabel("Months")
plt.ylabel("Temperature (C)")

plt.rcParams['figure.figsize'] = [8,6]

# Save 
plt.savefig("Images/CA_temp.png")

#Show

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
#Precipitation variables

CA_rain = CA_df['Precipitation (mm)']
x_axis2 = CA_df['Date']

# %%
#Plot average precipitation

CA_avg2 = plt.plot(x_axis2, CA_rain, color="green", label="Avg Precipitation (mm)")

tick_locations = [value for value in x_axis2]
plt.xticks(tick_locations, x_axis2, rotation=90)

#Formatting
plt.title("Avg Precipitation (mm): San Diego, CA")
plt.xlabel("Months")
plt.ylabel("Precipitation (mm)")

plt.rcParams['figure.figsize'] = [8,6]

# Save 
plt.savefig("Images/CA_rain.png")

#Show
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
#Michoacan csv

Mich_file = "Resources/Michoacan_weather_data.csv"

# %%
Mich_df = pd.read_csv(Mich_file)
Mich_df.head()
# Out:
#          Date  Temperature (C)  Precipitation (mm)
# 0  2015-01-31        25.667419            0.020323
# 1  2015-02-28        24.952500            0.043929
# 2  2015-03-31        26.046774            0.047742
# 3  2015-04-30        26.898333            0.017667
# 4  2015-05-31        27.031613            0.139355

# %%
#Set variables for plotting

Mich_temp = Mich_df['Temperature (C)']
x_axis3 = Mich_df['Date']

# %%
#Plot average temp Mich

Mich_avg1 = plt.plot(x_axis3, Mich_temp, color="blue", label="Avg Temperature (C)")

tick_locations = [value for value in x_axis3]
plt.xticks(tick_locations, x_axis3, rotation=90)

#Formatting
plt.title("Average Temp(C): Michoacan, Mexico")
plt.xlabel("Months")
plt.ylabel("Temperature (C)")

plt.rcParams['figure.figsize'] = [8,6]

# Save 
plt.savefig("Images/Michoacan_temp.png")

#Show

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
#Precipitation variables Michoaca

Mich_rain = Mich_df['Precipitation (mm)']
x_axis6 = Mich_df['Date']

# %%
#Plot average precipitation Michoaca

Mich_avg2 = plt.plot(x_axis6, Mich_rain, color="green", label="Avg Precipitation (mm)")

tick_locations = [value for value in x_axis6]
plt.xticks(tick_locations, x_axis6, rotation=90)

#Formatting
plt.title("Avg Precipitation (mm): Michoacan, Mexico")
plt.xlabel("Months")
plt.ylabel("Precipitation (mm)")

plt.rcParams['figure.figsize'] = [8,6]

# Save 
plt.savefig("Images/Michoacan_rain.png")

#Show
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">
