# %%
# %matplotlib notebook

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#Florida csv

FL_file = "Resources/FL_weather_data2.csv"

# %%
FL_df = pd.read_csv(FL_file)
FL_df.head()
# Out:
#          Date  Temperature (C)  Precipitation (mm)
# 0  2015-01-31        20.837742            0.070000
# 1  2015-02-28        19.554286            0.143571
# 2  2015-03-31        23.192903            0.060000
# 3  2015-04-30        25.238333            0.152000
# 4  2015-05-31        25.662903            0.126452

# %%
#Reformat date column

# %%
#Set variables for plotting

FL_temp = FL_df['Temperature (C)']
x_axis1 = FL_df['Date']

# %%
#Plot average temp 

FL_avg1 = plt.plot(x_axis1, FL_temp, color="blue", label="Avg Temperature (C)")

tick_locations = [value for value in x_axis1]
plt.xticks(tick_locations, x_axis1, rotation=90)

#Formatting
plt.title("Average Temp(C): Palm Beach, FL")
plt.xlabel("Months")
plt.ylabel("Temperature (C)")

plt.rcParams['figure.figsize'] = [8,6]

#Show

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
FL_rain = FL_df['Precipitation (mm)']
x_axis2 = FL_df['Date']

# %%
#Plot average precipitation

FL_avg2 = plt.plot(x_axis2, FL_rain, color="green", label="Avg Precipitation (mm)")

tick_locations = [value for value in x_axis2]
plt.xticks(tick_locations, x_axis2, rotation=90)

#Formatting
plt.title("Avg Precipitation (mm): Palm Beach, FL")
plt.xlabel("Months")
plt.ylabel("Precipitation (mm)")

plt.rcParams['figure.figsize'] = [8,6]

#Show
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
#Texas csv

TX_file = "Resources/TX_weather_data2.csv"

# %%
TX_df = pd.read_csv(TX_file)
TX_df.head()
# Out:
#          Date  Temperature (C)  Precipitation (mm)
# 0  2015-01-31        11.543226            0.067742
# 1  2015-02-28        14.170357            0.076429
# 2  2015-03-31        17.577097            0.182258
# 3  2015-04-30        23.107667            0.201333
# 4  2015-05-31        25.879032            0.273871

# %%
#Reformat date column

# %%
#Set variables for plotting

TX_temp = TX_df['Temperature (C)']
x_axis3 = TX_df['Date']

# %%
#Plot average temp 

TX_avg1 = plt.plot(x_axis3, TX_temp, color="blue", label="Avg Temperature (C)")

tick_locations = [value for value in x_axis3]
plt.xticks(tick_locations, x_axis3, rotation=90)

#Formatting
plt.title("Average Temp(C): Corpus Christi, TX")
plt.xlabel("Months")
plt.ylabel("Temperature (C)")

plt.rcParams['figure.figsize'] = [8,6]

#Show

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
TX_rain = TX_df['Precipitation (mm)']
x_axis4 = TX_df['Date']

# %%
#Plot average precipitation

TX_avg2 = plt.plot(x_axis4, TX_rain, color="green", label="Avg Precipitation (mm)")

tick_locations = [value for value in x_axis4]
plt.xticks(tick_locations, x_axis4, rotation=90)

#Formatting
plt.title("Avg Precipitation (mm): Corpus Christi, TX")
plt.xlabel("Months")
plt.ylabel("Precipitation (mm)")

plt.rcParams['figure.figsize'] = [8,6]

#Show
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
#Louisiana csv

LA_file = "Resources/LA_weather_data2.csv"

# %%
LA_df = pd.read_csv(LA_file)
LA_df.head()
# Out:
#          Date  Temperature (C)  Precipitation (mm)
# 0  2015-01-31         9.650645            0.184194
# 1  2015-02-28        10.132500            0.115357
# 2  2015-03-31        17.836774            0.229355
# 3  2015-04-30        21.865667            0.355000
# 4  2015-05-31        24.223871            0.254194

# %%
#Reformat date column

# %%
#Set variables for plotting

LA_temp = LA_df['Temperature (C)']
x_axis5 = LA_df['Date']

# %%
#Plot average temp 

LA_avg1 = plt.plot(x_axis5, LA_temp, color="blue", label="Avg Temperature (C)")

tick_locations = [value for value in x_axis5]
plt.xticks(tick_locations, x_axis5, rotation=90)

#Formatting
plt.title("Average Temp(C): Iberville, LA")
plt.xlabel("Months")
plt.ylabel("Temperature (C)")

plt.rcParams['figure.figsize'] = [8,6]

#Show

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
LA_rain = LA_df['Precipitation (mm)']
x_axis6 = LA_df['Date']

# %%
#Plot average precipitation

LA_avg2 = plt.plot(x_axis6, TX_rain, color="green", label="Avg Precipitation (mm)")

tick_locations = [value for value in x_axis6]
plt.xticks(tick_locations, x_axis6, rotation=90)

#Formatting
plt.title("Avg Precipitation (mm): Iberville, LA")
plt.xlabel("Months")
plt.ylabel("Precipitation (mm)")

plt.rcParams['figure.figsize'] = [8,6]

#Show
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">
