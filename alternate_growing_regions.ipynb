# %%
# %matplotlib notebook

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#Florida csv

FL_file = "Resources/FL_weather_data2.csv"

# %%
FL_df = pd.read_csv(FL_file)
FL_df.head()
# Out:
#          Date  Temperature (C)  Precipitation (mm)
# 0  2015-01-31        20.837742            0.070000
# 1  2015-02-28        19.554286            0.143571
# 2  2015-03-31        23.192903            0.060000
# 3  2015-04-30        25.238333            0.152000
# 4  2015-05-31        25.662903            0.126452

# %%
#Set variables for plotting

FL_temp = FL_df['Temperature (C)']
FL_rain = FL_df['Precipitation (mm)']
x_axis1 = FL_df['Date']

# %%
#Plot average temp 

FL_avg1 = plt.plot(x_axis1, FL_temp, color="blue", label="Avg Temperature (C)")

tick_locations = [value for value in x_axis1]
plt.xticks(tick_locations, x_axis1, rotation=90)

#Formatting
plt.title("Average Temp(C): Palm Beach, FL")
plt.xlabel("Months")
plt.ylabel("Temperature (C)")

plt.rcParams['figure.figsize'] = [8,6]

#Show

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">
